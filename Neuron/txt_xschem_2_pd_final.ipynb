# %%
import pandas as pd
import matplotlib.pyplot as plt
emp=[]
# Define the file path
file_path = 'simu_1pf.txt'
data = pd.read_csv(file_path, header = None)
for a in range(1,len(data)):
    tmp=[a for a in data.iloc[a][0].split(' ') if a != '']
    emp.append(tmp)
    #print(tmp)
    #emp.append(tmp)
emp=pd.DataFrame(emp)
#emp
#print(data.iloc[0][0])
#print(data.iloc[1][0])

# %%
x=[]
y=[]
for a in range(len(emp.columns)):
    if a % 2 == 0:
        # Even column index, add data points to x
        x.append(emp.iloc[:, a].values.astype(float))
    else:
        # Odd column index, add data points to y
        y.append(emp.iloc[:, a].values.astype(float))

# %% [markdown]
# ## ploteo de las salidas de impulsos, es opcional ##

# %%
#for a in zip(x,y):
#    plt.figure()
#    plt.plot(a[0],a[1])

# %%
new_arra=[]
for a in y:
    result = [True if a >= 1.65 else False for a in a]
    #plt.plot(result)
    index=[]
    for b in range(len(result)-1):
        if result[b] == 1 and result[b+1] == 0:
            index.append(True)
        else:
            index.append(False)
    new_arra.append(index)

# %%
vals=[]
for a in range(len(y)):
    mask=new_arra[a]
    vari=x[a][:-1][mask]
    print('Time between spikes for the {}th simulation is {}'.format(a+1,vari))
    if len(vari)>=2:
        tm_diff=vari[-1]-vari[-2]
        vals.append(1/tm_diff)
        print(f"Spike frequency of the impulses is {1/tm_diff}")
    else:
        print('No spikes detected')
        vals.append(0)
# Out:
# Time between spikes for the 1th simulation is [1.0153e-06]
# No spikes detected
# Time between spikes for the 2th simulation is [1.0153e-06]
# No spikes detected
# Time between spikes for the 3th simulation is [1.0153e-06]
# No spikes detected
# Time between spikes for the 4th simulation is [1.0153e-06]
# No spikes detected
# Time between spikes for the 5th simulation is [1.0252e-06]
# No spikes detected
# Time between spikes for the 6th simulation is [1.0252e-06]
# No spikes detected
# Time between spikes for the 7th simulation is [1.0252e-06]
# No spikes detected
# Time between spikes for the 8th simulation is [1.0252e-06]
# No spikes detected
# Time between spikes for the 9th simulation is [1.0352e-06]
# No spikes detected
# Time between spikes for the 10th simulation is [1.0352e-06]
# No spikes detected
# Time between spikes for the 11th simulation is [1.0352e-06]
# No spikes detected
# Time between spikes for the 12th simulation is [1.0452e-06]
# No spikes detected
# Time between spikes for the 13th simulation is [1.0452e-06]
# No spikes detected
# Time between spikes for the 14th simulation is [1.0452e-06]
# No spikes detected
# Time between spikes for the 15th simulation is [1.0452e-06]
# No spikes detected
# Time between spikes for the 16th simulation is [1.0552e-06]
# No spikes detected
# Time between spikes for the 17th simulation is [1.0552e-06]
# No spikes detected
# Time between spikes for the 18th simulation is [1.0552e-06]
# No spikes detected
# Time between spikes for the 19th simulation is [1.0652e-06]
# No spikes detected
# Time between spikes for the 20th simulation is [1.0652e-06]
# No spikes detected
# Time between spikes for the 21th simulation is [1.0652e-06]
# No spikes detected
# Time between spikes for the 22th simulation is [1.0752e-06]
# No spikes detected
# Time between spikes for the 23th simulation is [1.0752e-06]
# No spikes detected
# Time between spikes for the 24th simulation is [1.0752e-06]
# No spikes detected
# Time between spikes for the 25th simulation is [1.0852e-06]
# No spikes detected
# Time between spikes for the 26th simulation is [1.0852e-06]
# No spikes detected
# Time between spikes for the 27th simulation is [1.0852e-06]
# No spikes detected
# Time between spikes for the 28th simulation is [1.0852e-06]
# No spikes detected
# Time between spikes for the 29th simulation is [1.0952e-06]
# No spikes detected
# Time between spikes for the 30th simulation is [1.0952e-06]
# No spikes detected
# Time between spikes for the 31th simulation is [1.0952e-06 4.9615e-05]
# Spike frequency of the impulses is 20610.142663407518
# Time between spikes for the 32th simulation is [1.1052e-06 4.7365e-05]
# Spike frequency of the impulses is 21617.041145876115
# Time between spikes for the 33th simulation is [1.1052e-06 4.5325e-05]
# Spike frequency of the impulses is 22614.303999565807
# Time between spikes for the 34th simulation is [1.1051e-06 4.3465e-05]
# Spike frequency of the impulses is 23607.23231169101
# Time between spikes for the 35th simulation is [1.1151e-06 4.1765e-05]
# Spike frequency of the impulses is 24600.306519819238
# Time between spikes for the 36th simulation is [1.1151e-06 4.0195e-05]
# Spike frequency of the impulses is 25588.601813208326
# Time between spikes for the 37th simulation is [1.1151e-06 3.8755e-05]
# Spike frequency of the impulses is 26567.55198605735
# Time between spikes for the 38th simulation is [1.1251e-06 3.7415e-05]
# Spike frequency of the impulses is 27555.876428427746
# Time between spikes for the 39th simulation is [1.1251e-06 3.6185e-05]
# Spike frequency of the impulses is 28522.6141546325
# Time between spikes for the 40th simulation is [1.1251e-06 3.5025e-05]
# Spike frequency of the impulses is 29498.612090301154
# Time between spikes for the 41th simulation is [1.1351e-06 3.3955e-05]
# Spike frequency of the impulses is 30469.318919314195
# Time between spikes for the 42th simulation is [1.1351e-06 3.2945e-05]
# Spike frequency of the impulses is 31436.753966532437
# Time between spikes for the 43th simulation is [1.1451e-06 3.2005e-05]
# Spike frequency of the impulses is 32404.512004251465
# Time between spikes for the 44th simulation is [1.1451e-06 3.1125e-05]
# Spike frequency of the impulses is 33355.681640032155
# Time between spikes for the 45th simulation is [1.1451e-06 3.0295e-05]
# Spike frequency of the impulses is 34305.43501006864
# Time between spikes for the 46th simulation is [1.1551e-06 2.9505e-05]
# Spike frequency of the impulses is 35273.493028194105
# Time between spikes for the 47th simulation is [1.1551e-06 2.8765e-05]
# Spike frequency of the impulses is 36218.89249870517
# Time between spikes for the 48th simulation is [1.1551e-06 2.8075e-05]
# Spike frequency of the impulses is 37147.24051723817
# Time between spikes for the 49th simulation is [1.1651e-06 2.7405e-05]
# Spike frequency of the impulses is 38109.90133346545
# Time between spikes for the 50th simulation is [1.1651e-06 2.6785e-05]
# Spike frequency of the impulses is 39032.158595466804
# Time between spikes for the 51th simulation is [1.1651e-06 2.6185e-05]
# Spike frequency of the impulses is 39968.18532448171
# Time between spikes for the 52th simulation is [1.1751e-06 2.5615e-05]
# Spike frequency of the impulses is 40916.69769516242
# Time between spikes for the 53th simulation is [1.1751e-06 2.5075e-05 4.8975e-05]
# Spike frequency of the impulses is 41841.00418410042
# Time between spikes for the 54th simulation is [1.1851e-06 2.4565e-05 4.7945e-05]
# Spike frequency of the impulses is 42771.599657827195
# Time between spikes for the 55th simulation is [1.1851e-06 2.4075e-05 4.6965e-05]
# Spike frequency of the impulses is 43687.1996505024
# Time between spikes for the 56th simulation is [1.1851e-06 2.3605e-05 4.6025e-05]
# Spike frequency of the impulses is 44603.03300624442
# Time between spikes for the 57th simulation is [1.1951e-06 2.3155e-05 4.5125e-05]
# Spike frequency of the impulses is 45516.61356395084
# Time between spikes for the 58th simulation is [1.1951e-06 2.2725e-05 4.4265e-05]
# Spike frequency of the impulses is 46425.25533890437
# Time between spikes for the 59th simulation is [1.2051e-06 2.2315e-05 4.3435e-05]
# Spike frequency of the impulses is 47348.48484848485
# Time between spikes for the 60th simulation is [1.2051e-06 2.1925e-05 4.2645e-05]
# Spike frequency of the impulses is 48262.54826254826
# Time between spikes for the 61th simulation is [1.2051e-06 2.1545e-05 4.1885e-05]
# Spike frequency of the impulses is 49164.20845624385
# Time between spikes for the 62th simulation is [1.2151e-06 2.1185e-05 4.1155e-05]
# Spike frequency of the impulses is 50075.1126690035
# Time between spikes for the 63th simulation is [1.2151e-06 2.0835e-05 4.0455e-05]
# Spike frequency of the impulses is 50968.399592252805
# Time between spikes for the 64th simulation is [1.2250e-06 2.0505e-05 3.9785e-05]
# Spike frequency of the impulses is 51867.21991701245
# Time between spikes for the 65th simulation is [1.2250e-06 2.0175e-05 3.9135e-05]
# Spike frequency of the impulses is 52742.61603375528
# Time between spikes for the 66th simulation is [1.2250e-06 1.9865e-05 3.8505e-05]
# Spike frequency of the impulses is 53648.0686695279
# Time between spikes for the 67th simulation is [1.2350e-06 1.9575e-05 3.7905e-05]
# Spike frequency of the impulses is 54555.37370430989
# Time between spikes for the 68th simulation is [1.2350e-06 1.9285e-05 3.7325e-05]
# Spike frequency of the impulses is 55432.37250554324
# Time between spikes for the 69th simulation is [1.2450e-06 1.9005e-05 3.6765e-05]
# Spike frequency of the impulses is 56306.30630630631
# Time between spikes for the 70th simulation is [1.2450e-06 1.8735e-05 3.6225e-05]
# Spike frequency of the impulses is 57175.52887364208
# Time between spikes for the 71th simulation is [1.2550e-06 1.8475e-05 3.5705e-05]
# Spike frequency of the impulses is 58038.30528148578
# Time between spikes for the 72th simulation is [1.2550e-06 1.8225e-05 3.5195e-05]
# Spike frequency of the impulses is 58927.51915144373
# Time between spikes for the 73th simulation is [1.2550e-06 1.7985e-05 3.4705e-05]
# Spike frequency of the impulses is 59808.61244019139
# Time between spikes for the 74th simulation is [1.2650e-06 1.7745e-05 3.4235e-05]
# Spike frequency of the impulses is 60642.813826561556
# Time between spikes for the 75th simulation is [1.2650e-06 1.7525e-05 3.3775e-05]
# Spike frequency of the impulses is 61538.46153846153
# Time between spikes for the 76th simulation is [1.2750e-06 1.7305e-05 3.3325e-05 4.9355e-05]
# Spike frequency of the impulses is 62383.03181534622
# Time between spikes for the 77th simulation is [1.2750e-06 1.7085e-05 3.2895e-05 4.8715e-05]
# Spike frequency of the impulses is 63211.12515802783
# Time between spikes for the 78th simulation is [1.2850e-06 1.6885e-05 3.2485e-05 4.8085e-05]
# Spike frequency of the impulses is 64102.5641025641
# Time between spikes for the 79th simulation is [1.2850e-06 1.6685e-05 3.2075e-05 4.7475e-05]
# Spike frequency of the impulses is 64935.064935064926
# Time between spikes for the 80th simulation is [1.2950e-06 1.6485e-05 3.1685e-05 4.6885e-05]
# Spike frequency of the impulses is 65789.4736842105
# Time between spikes for the 81th simulation is [1.2950e-06 1.6305e-05 3.1305e-05 4.6305e-05]
# Spike frequency of the impulses is 66666.66666666667
# Time between spikes for the 82th simulation is [1.3050e-06 1.6115e-05 3.0935e-05 4.5755e-05]
# Spike frequency of the impulses is 67476.38326585696
# Time between spikes for the 83th simulation is [1.3050e-06 1.5945e-05 3.0575e-05 4.5215e-05]
# Spike frequency of the impulses is 68306.01092896174
# Time between spikes for the 84th simulation is [1.3150e-06 1.5765e-05 3.0225e-05 4.4685e-05]
# Spike frequency of the impulses is 69156.29322268325
# Time between spikes for the 85th simulation is [1.3150e-06 1.5605e-05 2.9885e-05 4.4175e-05]
# Spike frequency of the impulses is 69979.00629811054
# Time between spikes for the 86th simulation is [1.3250e-06 1.5435e-05 2.9555e-05 4.3675e-05]
# Spike frequency of the impulses is 70821.52974504251
# Time between spikes for the 87th simulation is [1.3250e-06 1.5285e-05 2.9235e-05 4.3195e-05]
# Spike frequency of the impulses is 71633.23782234956
# Time between spikes for the 88th simulation is [1.3350e-06 1.5125e-05 2.8925e-05 4.2715e-05]
# Spike frequency of the impulses is 72516.3161711385
# Time between spikes for the 89th simulation is [1.3350e-06 1.4975e-05 2.8615e-05 4.2265e-05]
# Spike frequency of the impulses is 73260.07326007324
# Time between spikes for the 90th simulation is [1.3450e-06 1.4835e-05 2.8325e-05 4.1815e-05]
# Spike frequency of the impulses is 74128.98443291328
# Time between spikes for the 91th simulation is [1.3450e-06 1.4695e-05 2.8035e-05 4.1375e-05]
# Spike frequency of the impulses is 74962.51874062966
# Time between spikes for the 92th simulation is [1.3550e-06 1.4555e-05 2.7755e-05 4.0955e-05]
# Spike frequency of the impulses is 75757.57575757579
# Time between spikes for the 93th simulation is [1.3549e-06 1.4415e-05 2.7485e-05 4.0545e-05]
# Spike frequency of the impulses is 76569.67840735069
# Time between spikes for the 94th simulation is [1.3649e-06 1.4285e-05 2.7215e-05 4.0135e-05]
# Spike frequency of the impulses is 77399.38080495354
# Time between spikes for the 95th simulation is [1.3649e-06 1.4165e-05 2.6955e-05 3.9745e-05]
# Spike frequency of the impulses is 78186.08287724784
# Time between spikes for the 96th simulation is [1.3749e-06 1.4035e-05 2.6705e-05 3.9365e-05]
# Spike frequency of the impulses is 78988.94154818325
# Time between spikes for the 97th simulation is [1.3749e-06 1.3915e-05 2.6455e-05 3.8995e-05]
# Spike frequency of the impulses is 79744.81658692184
# Time between spikes for the 98th simulation is [1.3849e-06 1.3795e-05 2.6215e-05 3.8625e-05]
# Spike frequency of the impulses is 80580.17727639002
# Time between spikes for the 99th simulation is [1.3849e-06 1.3685e-05 2.5975e-05 3.8265e-05]
# Spike frequency of the impulses is 81366.96501220505
# Time between spikes for the 100th simulation is [1.3949e-06 1.3575e-05 2.5745e-05 3.7925e-05]
# Spike frequency of the impulses is 82101.80623973729
# Time between spikes for the 101th simulation is [1.4049e-06 1.3465e-05 2.5525e-05 3.7585e-05 4.9645e-05]
# Spike frequency of the impulses is 82918.73963515753
# Time between spikes for the 102th simulation is [1.4049e-06 1.3355e-05 2.5305e-05 3.7255e-05 4.9195e-05]
# Spike frequency of the impulses is 83752.09380234507
# Time between spikes for the 103th simulation is [1.4149e-06 1.3255e-05 2.5085e-05 3.6925e-05 4.8765e-05]
# Spike frequency of the impulses is 84459.4594594595
# Time between spikes for the 104th simulation is [1.4149e-06 1.3145e-05 2.4885e-05 3.6615e-05 4.8345e-05]
# Spike frequency of the impulses is 85251.49190110828
# Time between spikes for the 105th simulation is [1.4249e-06 1.3055e-05 2.4675e-05 3.6305e-05 4.7925e-05]
# Spike frequency of the impulses is 86058.51979345955
# Time between spikes for the 106th simulation is [1.4249e-06 1.2955e-05 2.4475e-05 3.6005e-05 4.7525e-05]
# Spike frequency of the impulses is 86805.55555555552
# Time between spikes for the 107th simulation is [1.4349e-06 1.2855e-05 2.4285e-05 3.5705e-05 4.7125e-05]
# Spike frequency of the impulses is 87565.67425569175
# Time between spikes for the 108th simulation is [1.4449e-06 1.2765e-05 2.4095e-05 3.5415e-05 4.6745e-05]
# Spike frequency of the impulses is 88261.25330979699
# Time between spikes for the 109th simulation is [1.4449e-06 1.2675e-05 2.3905e-05 3.5135e-05 4.6365e-05]
# Spike frequency of the impulses is 89047.19501335708
# Time between spikes for the 110th simulation is [1.4549e-06 1.2585e-05 2.3725e-05 3.4855e-05 4.5995e-05]
# Spike frequency of the impulses is 89766.60682226208
# Time between spikes for the 111th simulation is [1.4649e-06 1.2505e-05 2.3545e-05 3.4585e-05 4.5635e-05]
# Spike frequency of the impulses is 90497.7375565611
# Time between spikes for the 112th simulation is [1.4649e-06 1.2415e-05 2.3375e-05 3.4325e-05 4.5275e-05]
# Spike frequency of the impulses is 91324.20091324199
# Time between spikes for the 113th simulation is [1.4749e-06 1.2335e-05 2.3205e-05 3.4065e-05 4.4925e-05]
# Spike frequency of the impulses is 92081.03130755064
# Time between spikes for the 114th simulation is [1.4849e-06 1.2255e-05 2.3035e-05 3.3815e-05 4.4595e-05]
# Spike frequency of the impulses is 92764.37847866418
# Time between spikes for the 115th simulation is [1.4849e-06 1.2185e-05 2.2875e-05 3.3565e-05 4.4255e-05]
# Spike frequency of the impulses is 93545.36950420954
# Time between spikes for the 116th simulation is [1.4949e-06 1.2105e-05 2.2715e-05 3.3325e-05 4.3935e-05]
# Spike frequency of the impulses is 94250.70688030159
# Time between spikes for the 117th simulation is [1.5049e-06 1.2025e-05 2.2555e-05 3.3085e-05 4.3615e-05]
# Spike frequency of the impulses is 94966.76163342828
# Time between spikes for the 118th simulation is [1.5049e-06 1.1955e-05 2.2405e-05 3.2855e-05 4.3305e-05]
# Spike frequency of the impulses is 95693.77990430626
# Time between spikes for the 119th simulation is [1.5149e-06 1.1885e-05 2.2255e-05 3.2625e-05 4.2995e-05]
# Spike frequency of the impulses is 96432.01542912249
# Time between spikes for the 120th simulation is [1.5249e-06 1.1815e-05 2.2115e-05 3.2405e-05 4.2705e-05]
# Spike frequency of the impulses is 97087.3786407767
# Time between spikes for the 121th simulation is [1.5249e-06 1.1745e-05 2.1965e-05 3.2185e-05 4.2405e-05]
# Spike frequency of the impulses is 97847.35812133072
# Time between spikes for the 122th simulation is [1.5348e-06 1.1685e-05 2.1825e-05 3.1975e-05 4.2125e-05]
# Spike frequency of the impulses is 98522.1674876847
# Time between spikes for the 123th simulation is [1.5448e-06 1.1615e-05 2.1695e-05 3.1765e-05 4.1845e-05]
# Spike frequency of the impulses is 99206.34920634922
# Time between spikes for the 124th simulation is [1.5548e-06 1.1555e-05 2.1555e-05 3.1565e-05 4.1565e-05]
# Spike frequency of the impulses is 100000.00000000001
# Time between spikes for the 125th simulation is [1.5548e-06 1.1495e-05 2.1425e-05 3.1365e-05 4.1295e-05]
# Spike frequency of the impulses is 100704.9345417926
# Time between spikes for the 126th simulation is [1.5648e-06 1.1435e-05 2.1305e-05 3.1165e-05 4.1035e-05]
# Spike frequency of the impulses is 101317.12259371828
# Time between spikes for the 127th simulation is [1.5748e-06 1.1375e-05 2.1175e-05 3.0975e-05 4.0775e-05]
# Spike frequency of the impulses is 102040.8163265306
# Time between spikes for the 128th simulation is [1.5848e-06 1.1315e-05 2.1055e-05 3.0785e-05 4.0525e-05]
# Spike frequency of the impulses is 102669.40451745375
# Time between spikes for the 129th simulation is [1.5948e-06 1.1265e-05 2.0935e-05 3.0605e-05 4.0275e-05 4.9955e-05]
# Spike frequency of the impulses is 103305.785123967
# Time between spikes for the 130th simulation is [1.5948e-06 1.1205e-05 2.0815e-05 3.0425e-05 4.0035e-05 4.9645e-05]
# Spike frequency of the impulses is 104058.27263267424
# Time between spikes for the 131th simulation is [1.6048e-06 1.1155e-05 2.0705e-05 3.0255e-05 3.9795e-05 4.9345e-05]
# Spike frequency of the impulses is 104712.04188481673
# Time between spikes for the 132th simulation is [1.6148e-06 1.1105e-05 2.0595e-05 3.0075e-05 3.9565e-05 4.9055e-05]
# Spike frequency of the impulses is 105374.07797681772
# Time between spikes for the 133th simulation is [1.6248e-06 1.1055e-05 2.0485e-05 2.9905e-05 3.9335e-05 4.8765e-05]
# Spike frequency of the impulses is 106044.53870625667
# Time between spikes for the 134th simulation is [1.6348e-06 1.1005e-05 2.0375e-05 2.9745e-05 3.9115e-05 4.8485e-05]
# Spike frequency of the impulses is 106723.58591248665
# Time between spikes for the 135th simulation is [1.6448e-06 1.0955e-05 2.0265e-05 2.9585e-05 3.8895e-05 4.8215e-05]
# Spike frequency of the impulses is 107296.1373390558
# Time between spikes for the 136th simulation is [1.6548e-06 1.0905e-05 2.0165e-05 2.9425e-05 3.8685e-05 4.7945e-05]
# Spike frequency of the impulses is 107991.36069114467
# Time between spikes for the 137th simulation is [1.6548e-06 1.0865e-05 2.0065e-05 2.9275e-05 3.8475e-05 4.7675e-05]
# Spike frequency of the impulses is 108695.65217391304
# Time between spikes for the 138th simulation is [1.6648e-06 1.0815e-05 1.9965e-05 2.9115e-05 3.8275e-05 4.7425e-05]
# Spike frequency of the impulses is 109289.61748633882
# Time between spikes for the 139th simulation is [1.6748e-06 1.0775e-05 1.9875e-05 2.8975e-05 3.8065e-05 4.7165e-05]
# Spike frequency of the impulses is 109890.10989010992
# Time between spikes for the 140th simulation is [1.6848e-06 1.0735e-05 1.9785e-05 2.8825e-05 3.7875e-05 4.6915e-05]
# Spike frequency of the impulses is 110619.46902654866
# Time between spikes for the 141th simulation is [1.6948e-06 1.0695e-05 1.9685e-05 2.8685e-05 3.7685e-05 4.6675e-05]
# Spike frequency of the impulses is 111234.70522803115
# Time between spikes for the 142th simulation is [1.7048e-06 1.0655e-05 1.9605e-05 2.8545e-05 3.7495e-05 4.6445e-05]
# Spike frequency of the impulses is 111731.84357541898
# Time between spikes for the 143th simulation is [1.7148e-06 1.0615e-05 1.9515e-05 2.8415e-05 3.7315e-05 4.6205e-05]
# Spike frequency of the impulses is 112485.93925759275
# Time between spikes for the 144th simulation is [1.7248e-06 1.0575e-05 1.9425e-05 2.8285e-05 3.7135e-05 4.5985e-05]
# Spike frequency of the impulses is 112994.3502824859
# Time between spikes for the 145th simulation is [1.7348e-06 1.0545e-05 1.9345e-05 2.8155e-05 3.6955e-05 4.5755e-05]
# Spike frequency of the impulses is 113636.36363636368
# Time between spikes for the 146th simulation is [1.7448e-06 1.0505e-05 1.9265e-05 2.8025e-05 3.6785e-05 4.5545e-05]
# Spike frequency of the impulses is 114155.25114155255
# Time between spikes for the 147th simulation is [1.7648e-06 1.0475e-05 1.9185e-05 2.7905e-05 3.6615e-05 4.5335e-05]
# Spike frequency of the impulses is 114678.89908256884
# Time between spikes for the 148th simulation is [1.7748e-06 1.0445e-05 1.9115e-05 2.7785e-05 3.6455e-05 4.5125e-05]
# Spike frequency of the impulses is 115340.25374855829
# Time between spikes for the 149th simulation is [1.7848e-06 1.0415e-05 1.9035e-05 2.7665e-05 3.6295e-05 4.4925e-05]
# Spike frequency of the impulses is 115874.855156431
# Time between spikes for the 150th simulation is [1.7948e-06 1.0385e-05 1.8965e-05 2.7555e-05 3.6135e-05 4.4725e-05]
# Spike frequency of the impulses is 116414.4353899883
# Time between spikes for the 151th simulation is [1.8048e-06 1.0355e-05 1.8895e-05 2.7445e-05 3.5985e-05 4.4535e-05]
# Spike frequency of the impulses is 116959.06432748541

# %%
plt.plot(vals,'r.')
